# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage import img_as_uint, img_as_float, img_as_int
from skimage.io import imread
from skimage.color import rgb2gray, gray2rgb
from scipy.fftpack import fft2, fftshift, ifft2, ifftshift
from skimage.filters import threshold_otsu
import copy

# %matplotlib inline

# %%
def show(collection):
    fig, ax = plt.subplots(nrows=1, ncols=len(collection), figsize=(10, 10))
    for i in range(len(collection)):
        ax[i].imshow(collection[i])
        ax[i].axis('off')

# %%
saturn = imread("images/saturn.jpg")
transform = fft2(saturn)
transform_shifted = fftshift(transform)
amp = np.abs(transform_shifted)
phase = np.arctan2(transform_shifted.imag, transform_shifted.real)
show([amp, np.log(amp)])
show([phase, np.log(phase)])
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:7: RuntimeWarning: divide by zero encountered in log
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:7: RuntimeWarning: invalid value encountered in log

# %%
plt.axis('off')
plt.imshow(gray2rgb(ifft2(transform).real))

# %%
def show_inverse(transform):
    plt.axis('off')
    plt.imshow(gray2rgb(ifft2(ifftshift(transform)).real))

# %%
high_filter = fftshift(transform)
high_filter[128:130, 128:130] = 0
show_inverse(high_filter)

# %%
low_filter = fftshift(transform)
low_filter[:,:] = 0
result = []
for i in range(129):
    low_filter[128-i:129+i, 128-i:129+i] = fftshift(transform)[128-i:129+i, 128-i:129+i]
    result.append(copy.deepcopy(low_filter))
result = [gray2rgb(ifft2(ifftshift(f)).real) for f in result]
show(result[:5])

# %%
show(result[-5:])
